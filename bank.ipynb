# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
from pandas import DataFrame

# %%
bank=pd.read_csv('/content/gdrive/MyDrive/Principles of Data Science/dataset/bank.csv')

# %%
bank.head()
# Out:
#    CustomerID     Name  Surname  ... JobClassification  DateJoined    Balance
# 0   100000001    Simon    Walsh  ...      White Collar   05.Jan.15  113810.15
# 1   400000002  Jasmine   Miller  ...       Blue Collar   06.Jan.15   36919.73
# 2   100000003     Liam    Brown  ...      White Collar   07.Jan.15  101536.83
# 3   300000004   Trevor     Parr  ...      White Collar   08.Jan.15    1421.52
# 4   100000005  Deirdre  Pullman  ...       Blue Collar   09.Jan.15   35639.79
#
# [5 rows x 9 columns]

# %%
bank.shape
# Out:
# (4014, 9)

# %%
bank.describe()
# Out:
#          CustomerID          Age        Balance
# count  4.014000e+03  4014.000000    4014.000000
# mean   1.696831e+08    38.611111   39766.448274
# std    8.865374e+07     9.819121   29859.489192
# min    1.000000e+08    15.000000      11.520000
# 25%    1.000020e+08    31.000000   16115.367500
# 50%    1.000038e+08    37.000000   33567.330000
# 75%    2.000031e+08    45.000000   57533.930000
# max    4.000038e+08    64.000000  183467.700000

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 0 to 4013
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         4014 non-null   int64
#  1   Name               4014 non-null   object
#  2   Surname            4014 non-null   object
#  3   Gender             4014 non-null   object
#  4   Age                4014 non-null   int64
#  5   Region             4014 non-null   object
#  6   JobClassification  4014 non-null   object
#  7   DateJoined         4014 non-null   object
#  8   Balance            4014 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 282.4+ KB

# %%
bank.describe(include="all")
# Out:
#           CustomerID   Name Surname Gender          Age   Region  \
# count   4.014000e+03   4014    4014   4014  4014.000000     4014
# unique           NaN    172     150      2          NaN        4
# top              NaN  Jason    Kerr   Male          NaN  England
# freq             NaN     42      41   2165          NaN     2159
# mean    1.696831e+08    NaN     NaN    NaN    38.611111      NaN
# std     8.865374e+07    NaN     NaN    NaN     9.819121      NaN
# min     1.000000e+08    NaN     NaN    NaN    15.000000      NaN
# 25%     1.000020e+08    NaN     NaN    NaN    31.000000      NaN
# 50%     1.000038e+08    NaN     NaN    NaN    37.000000      NaN
# 75%     2.000031e+08    NaN     NaN    NaN    45.000000      NaN
# max     4.000038e+08    NaN     NaN    NaN    64.000000      NaN
#
#        JobClassification DateJoined        Balance
# count               4014       4014    4014.000000
# unique                 3        307            NaN
# ...

# %% [markdown]
# CONVERTING STRINGS TO CATEORIES

# %%
bank['Gender'].astype('category')
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3         Male
# 4       Female
#          ...
# 4009      Male
# 4010      Male
# 4011    Female
# 4012      Male
# 4013      Male
# Name: Gender, Length: 4014, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
bank['Gender']=bank['Gender'].astype('category')

# %%
bank['Region']=bank['Region'].astype('category')

# %%
bank.describe(include='category')
# Out:
#        Gender   Region
# count    4014     4014
# unique      2        4
# top      Male  England
# freq     2165     2159

# %% [markdown]
# TYPE CONVERSION USING PROGRAMMING CONSTRUCTS

# %%
for col in['Gender','Region']:
  bank[col]=bank[col].astype('category')

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 0 to 4013
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         4014 non-null   int64
#  1   Name               4014 non-null   object
#  2   Surname            4014 non-null   object
#  3   Gender             4014 non-null   category
#  4   Age                4014 non-null   int64
#  5   Region             4014 non-null   category
#  6   JobClassification  4014 non-null   object
#  7   DateJoined         4014 non-null   object
#  8   Balance            4014 non-null   float64
# dtypes: category(2), float64(1), int64(2), object(4)
# memory usage: 227.8+ KB

# %%
bank['Balance'].mean()
# Out:
# 39766.4482735426

# %%
sal=bank['Balance']

# %%
sal.min(),sal.max(),sal.mean(),sal.median()
# Out:
# (11.52, 183467.7, 39766.4482735426, 33567.33)

# %%
bank.describe()
# Out:
#          CustomerID          Age        Balance
# count  4.014000e+03  4014.000000    4014.000000
# mean   1.696831e+08    38.611111   39766.448274
# std    8.865374e+07     9.819121   29859.489192
# min    1.000000e+08    15.000000      11.520000
# 25%    1.000020e+08    31.000000   16115.367500
# 50%    1.000038e+08    37.000000   33567.330000
# 75%    2.000031e+08    45.000000   57533.930000
# max    4.000038e+08    64.000000  183467.700000

# %% [markdown]
# HISTOGRAM IN SEABORN

# %%
import seaborn as sns
sns.histplot(x=bank['Balance'])
# Out:
# <Axes: xlabel='Balance', ylabel='Count'>

# %%
sns.histplot(x=bank['Balance'],bins=10,kde=True)
# Out:
# <Axes: xlabel='Balance', ylabel='Count'>

# %%
sns.histplot(x=bank['Balance'],bins=10,kde=False,stat='probability',color='green')
# Out:
# <Axes: xlabel='Balance', ylabel='Probability'>

# %% [markdown]
# FILTERING DATA

# %%
bank['Gender']=='Female'
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 4009    False
# 4010    False
# 4011     True
# 4012    False
# 4013    False
# Name: Gender, Length: 4014, dtype: bool

# %%
bank[bank['Gender']=='Female']
# Out:
#       CustomerID      Name   Surname  ... JobClassification  DateJoined    Balance
# 1      400000002   Jasmine    Miller  ...       Blue Collar   06.Jan.15   36919.73
# 4      100000005   Deirdre   Pullman  ...       Blue Collar   09.Jan.15   35639.79
# 5      300000006       Ava   Coleman  ...       Blue Collar   09.Jan.15  122443.77
# 6      100000007   Dorothy   Thomson  ...       Blue Collar   11.Jan.15   42879.84
# 7      200000008      Lisa      Knox  ...             Other   11.Jan.15   36680.17
# ...          ...       ...       ...  ...               ...         ...        ...
# 4003   100004004      Jane  Hemmings  ...       Blue Collar   30.Dec.15   68518.55
# 4005   100004006  Kimberly      Gray  ...             Other   30.Dec.15   64470.77
# 4006   100004007    Rachel    Davies  ...       Blue Collar   30.Dec.15    4561.22
# 4008   200004009    Alison     Quinn  ...             Other   30.Dec.15   73503.90
# ...

# %%
FemaleEmployees=bank[bank['Gender']=='Female']

# %%
type(FemaleEmployees)
# Out:
# pandas.core.frame.DataFrame

# %%
FemaleEmployees['Balance'].mean()
# Out:
# 39471.895116279076

# %%
round(FemaleEmployees['Balance'].mean(),2)
# Out:
# 39471.9

# %% [markdown]
# COMPLEX FILTERING DATA

# %%
(bank['Gender']=='Female') & (bank['Region']==1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4009    False
# 4010    False
# 4011    False
# 4012    False
# 4013    False
# Length: 4014, dtype: bool

# %%
bank[(bank['Gender']=='Female') & (bank['Region']==1)].shape
# Out:
# (0, 9)

# %%
bank[bank['Age']>=35]
# Out:
#       CustomerID       Name   Surname  ... JobClassification  DateJoined    Balance
# 2      100000003       Liam     Brown  ...      White Collar   07.Jan.15  101536.83
# 4      100000005    Deirdre   Pullman  ...       Blue Collar   09.Jan.15   35639.79
# 7      200000008       Lisa      Knox  ...             Other   11.Jan.15   36680.17
# 9      100000010    Dominic      Parr  ...      White Collar   12.Jan.15   10912.45
# 10     100000011    Dominic     Lewis  ...      White Collar   12.Jan.15   39667.83
# ...          ...        ...       ...  ...               ...         ...        ...
# 4008   200004009     Alison     Quinn  ...             Other   30.Dec.15   73503.90
# 4009   200004010        Sam     Lewis  ...             Other   30.Dec.15   19711.66
# 4010   200004011      Keith    Hughes  ...       Blue Collar   30.Dec.15   56069.72
# 4011   200004012     Hannah  Springer  ...             Other   30.Dec.15   59477.82
# ...

# %%
mgmt=[11,64,75]

# %%
bank[bank['Age'].isin(mgmt)]
# Out:
#       CustomerID         Name    Surname  Gender  Age    Region  \
# 631    200000632     Nicholas      Allan    Male   64  Scotland
# 841    200000842         Matt    Manning    Male   64  Scotland
# 1498   200001499      Cameron    Ellison    Male   64  Scotland
# 1586   200001587         Jake    Ellison    Male   64  Scotland
# 1608   200001609       Yvonne    Dickens  Female   64  Scotland
# 1639   200001640  Christopher  Underwood    Male   64  Scotland
# 2040   200002041      Abigail     Fraser  Female   64  Scotland
# 2055   200002056       Joshua       Carr    Male   64  Scotland
# 2310   200002311        Kevin     Howard    Male   64  Scotland
# 2352   200002353      Leonard      Lyman    Male   64  Scotland
# 2752   200002753          Ian     Hunter    Male   64  Scotland
# 2772   200002773         Alan     Watson    Male   64  Scotland
# 3676   200003677      Anthony      Lewis    Male   64  Scotland
# 4008   200004009       Alison      Quinn  Female   64  Scotland
# ...
